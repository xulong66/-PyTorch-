# %% [markdown]
# ### Dueling Network
# 在CartPole中，一般的DQN网络如下所示
# ![CartPole中Q网络的结构](./image/CartPole中Q网络的结构.jpg)
# Dueling Q-Network的结构如下：
# ![Dueling%20Q%20network](./image/Dueling%20Q%20network.jpg)
# 优势函数：$$A(s,right)=Q(s,right)-V(s)$$
# 在CartPole任务中，动作价值函数$Q$与状态$s$有关，可以获得动作的累计折扣奖励。例如可以取向右推或者向左推的动作使杆子跌倒所获得的总回报非常小。换句话说，$Q$函数所具有的信息分成仅有状态$s$组成的部分，和该动作确定的部分。因此Dueling Q-Network将Q函数分离为仅有状态$s$确定的部分$V(s)$和根据动作$a$确定的Advantage $A(s,a)$,在最终的输出层中将$V(s)$和$A(s,a)$相加求得$Q(s,a)$。
#
# Dueling Q-Network和DQN相比，优点是无论动作$a$如何，都可以逐步学习与$V(s)$相关的网络连接参数，学习所需的实验轮数比DQN更少，随着动作选择的增加，优势更加明显。
#
# Dueling Network的实现只需重写上一节中DDQN代码中构建神经网络的Net类，如下所示。

# %%
from torch import nn
import torch.nn.functional as F

class Net(nn.Module):
    def __init__(self, n_in, n_mid,n_out):
        super(Net,self).__init__()
        self.fc1 = nn.Linear(n_in,n_mid)
        self.fc2 = nn.Linear(n_mid,n_mid)
        #Dueling Network
        self.fc3_adv = nn.Linear(n_mid,n_out) #advantage
        self.fc3_v = nn.Linear(n_mid,1)  #v部分

    def forward(self,x):
        h1 = F.relu(self.fc1(x))
        h2 = F.relu(self.fc2(h1))

        adv = self.fc3_adv(h2)
        val = self.fc3_v(h2).expand(-1,adv.size(1))

        output = val + adv -adv.mean(1,keepdim=True).expand(-1,adv.size(1))

        return output

# %% [markdown]
# Dueling Network的实现是用PyTorch设计神经网络的一个很好的实践。在Net类的初始化函数中，与DDQN类似地构建输入层fc1和第一个隐藏层fc2，在最后创建与Advantage有关的层fc3_adv和与状态价值有关的层fc3_v。fc3_adv的输出数是可选动作的数量n_out。fc3_v表示状态价值，因此输出数为1。
#
# 在Net类的forward计算中，输入x经过fc1层，其输出经由ReLU传递给fc2，再通过ReLU传递给变量h2，h2再进入fc3_adv和fc3_v层。fc3_adv和fc3_v的输出不经过ReLU，分别作为变量adv和val保留。最后输出的动作价值通过adv和val的和来计算，用变量output表示。实际上，adv的大小是[minibatch的大小×动作类型的数量]，val的大小是[minibatch的大小×1]。因此，在求val时，使用expand调整它的大小，使其成为[minibatch的大小×动作的数量]。
#
# 请注意，在计算输出时，要从输出中减去Advantage的平均值。在其后的实现代码中，为了使得平均值的大小与变量adv的大小相匹配，执行了expand操作。我们接下来解释为什么使用val+adv-adv.mean而不是简单地输出val+adv。
#
# 减去平均值是因为如果只是简单地相加，由于动作的类型不同，其具有不同的偏置量，直接进行相加可能无法很好地完成学习。例如，假设Advantage在向右时偏差为b0。在这种状态下，为了通过相加正确地计算Q(s,右)，需要将-b0的偏置施加到V(s)上以抵消偏置b0。换句话说，偏置可以通过V(s)和Adv(s,右)消除，因此即使有一定偏置，也可以学习。
#
# 另一方面，如果向左的偏置是b1，则对应于状态价值的V(s)部分需要施加偏置-b1。也就是说，根据动作的类型，需要分别施加不同的偏置-b0和-b1到V(s)上。这是使学习不稳定的一个重要因素。为了尽可能避免这种情况，Dueling Network从输出中减去动作的平均值。
#
# 如果减去平均值，以向右为例，它将表示为
# $$Q(s,右)=V(s)+Adv(s,右)-(Adv(s,右)+Adu(s,左))/2$$
# 除了网络不同，其他和DDQN代码一样。

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation
from IPython.display import HTML
import gym
import random
import numpy as np

# 动画显示函数
def display_frames_as_gif(frames):
    plt.figure(figsize=(frames[0].shape[1] / 72.0, frames[0].shape[0] / 72.0), dpi=72)
    patch = plt.imshow(frames[0])
    plt.axis('off')

    def animate(i):
        patch.set_data(frames[i])
    
    anim = animation.FuncAnimation(plt.gcf(), animate, frames=len(frames), interval=50)
    anim.save('./image/movie_cartpole_DQN.mp4')
    plt.close()  # 防止显示两个输出
    return HTML(anim.to_jshtml())

from collections import namedtuple
#namedtuple就是有名字的元组，使得元组有键名，以便在DQN访问状态和动作值

Transition = namedtuple('Transition', ('state', 'action', 'next_state', 'reward'))

ENV = 'CartPole-v0'
GAMMA = 0.99
MAX_STEPS = 200
NUM_EPISODES = 500


#为了实现小批量学习，实现了内存类ReplayMemory来存储经验数据。ReplayMemory
class ReplayMemory:
    '''push函数保存步骤中的transition，随机选择的sample函数'''
    def __init__(self,CAPACITY) -> None:
        self.capacity = CAPACITY
        self.memory = []
        self.index = 0

    def push(self,state,action,state_next,reward):
        '''将transition(state,action,state_next,reward)保存在存储器中'''

        if len(self.memory) < self.capacity:
            self.memory.append(None)
        
        self.memory[self.index] = Transition(state,action,state_next,reward)

        self.index = (self.index + 1) % self.capacity #保存的index移动一位

    def sample(self,batch_size):
        return random.sample(self.memory,batch_size)
    
    def __len__(self):
        '''返回当前memory长度'''
        return len(self.memory)

# %%
# 这是一个类，充当代理的大脑，执行 DDQN

import random
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F

BATCH_SIZE = 32
CAPACITY = 10000

class Brain:
    def __init__(self, num_states, num_actions):
        self.num_actions = num_actions  # 获取 CartPole 的两个动作（向右或向左推）

        # 创建用于存储经验的内存对象
        self.memory = ReplayMemory(CAPACITY)

        # 构建神经网络
        n_in, n_mid, n_out = num_states, 32, num_actions
        self.main_q_network = Net(n_in, n_mid, n_out)  # 使用 Net 类
        self.target_q_network = Net(n_in, n_mid, n_out)  # 使用 Net 类
        print(self.main_q_network)  # 输出网络结构

        # 设置优化方法
        self.optimizer = optim.Adam(
            self.main_q_network.parameters(), lr=0.0001)

    def replay(self):
        '''使用 Experience Replay 学习网络的连接参数'''

        # 1. 检查内存大小
        if len(self.memory) < BATCH_SIZE:
            return

        # 2. 创建小批量
        self.batch, self.state_batch, self.action_batch, self.reward_batch, self.non_final_next_states = self.make_minibatch()

        # 3. 求出作为教师信号的 Q(s_t, a_t) 值
        self.expected_state_action_values = self.get_expected_state_action_values()

        # 4. 更新连接参数
        self.update_main_q_network()

    def decide_action(self, state, episode):
        '''根据当前状态决定动作'''
        # 逐渐只采取最优动作的 ε-greedy 法
        epsilon = 0.5 * (1 / (episode + 1))

        if epsilon <= np.random.uniform(0, 1):
            self.main_q_network.eval()  # 将网络切换到推理模式
            with torch.no_grad():
                action = self.main_q_network(state).max(1)[1].view(1, 1)
            # 提取网络输出的最大值的索引 = max(1)[1]
            # .view(1,1) 将 [torch.LongTensor of size 1] 转换为 size 1x1

        else:
            # 随机返回 0 或 1 动作
            action = torch.LongTensor(
                [[random.randrange(self.num_actions)]])  # 随机返回 0 或 1 动作
            # action 将是 [torch.LongTensor of size 1x1] 的形状

        return action

    def make_minibatch(self):
        '''2. 创建小批量'''

        # 2.1 从内存中取出小批量数据
        transitions = self.memory.sample(BATCH_SIZE)

        # 2.2 将各变量转换为小批量相对应的形状
        # transitions 包含 BATCH_SIZE 个 (state, action, state_next, reward)
        # 也就是说，有 (state, action, state_next, reward)×BATCH_SIZE
        # 我们想要将其转换为小批量的形式
        # 也就是 (state×BATCH_SIZE, action×BATCH_SIZE, state_next×BATCH_SIZE, reward×BATCH_SIZE)
        batch = Transition(*zip(*transitions))

        # 2.3 将每个变量的元素转换为小批量对应的形状，并转换为 Variable 以便网络处理
        # 例如，对于 state，将 BATCH_SIZE 个 [torch.FloatTensor of size 1x4] 转换为 [torch.FloatTensor of size BATCH_SIZEx4]
        # 创建状态、动作、奖励和非终止状态的小批量 Variable
        # cat 是 Concatenates（连接）的意思
        state_batch = torch.cat(batch.state)
        action_batch = torch.cat(batch.action)
        reward_batch = torch.cat(batch.reward)
        non_final_next_states = torch.cat([s for s in batch.next_state
                                           if s is not None])
        # 仅将存在的下一个状态进行连接，排除了 None 值

        return batch, state_batch, action_batch, reward_batch, non_final_next_states

    def get_expected_state_action_values(self):
        '''3. 计算作为教师信号的 Q(s_t, a_t) 值'''

        # 3.1 切换网络到推理模式
        self.main_q_network.eval()
        self.target_q_network.eval()

        # 3.2 计算网络输出的 Q(s_t, a_t)
        # self.model(state_batch) 输出左右两个动作的 Q 值
        # 形状为 [torch.FloatTensor of size BATCH_SIZEx2]
        # 为了得到执行动作 a_t 对应的 Q 值，我们根据 action_batch 中执行的动作是左还是右
        # 通过 gather 提取相应的 Q 值
        self.state_action_values = self.main_q_network(
            self.state_batch).gather(1, self.action_batch)

        # 3.3 计算 max{Q(s_{t+1}, a)} 值，注意检查下一个状态是否存在

        # 创建一个检查 cartpole 是否未完成并且 next_state 存在的索引掩码
        non_final_mask = torch.ByteTensor(tuple(map(lambda s: s is not None,
                                                    self.batch.next_state)))
        # 先将所有值设为 0
        next_state_values = torch.zeros(BATCH_SIZE)

        a_m = torch.zeros(BATCH_SIZE).type(torch.LongTensor)

        # 从 Main Q-Network 获取下一状态的最大 Q 值动作 a_m
        # 最后的 [1] 返回对应的动作索引
        a_m[non_final_mask] = self.main_q_network(
            self.non_final_next_states).detach().max(1)[1]

        # 筛选出存在的下一状态并将其尺寸从 32 转换为 32×1
        a_m_non_final_next_states = a_m[non_final_mask].view(-1, 1)

        # 从 Target Q-Network 获取对应 a_m 动作的 Q 值
        # 使用 detach() 提取
        # 使用 squeeze() 将尺寸从 [minibatch×1] 转换为 [minibatch]
        next_state_values[non_final_mask] = self.target_q_network(
            self.non_final_next_states).gather(1, a_m_non_final_next_states).detach().squeeze()

        # 3.4 根据 Q 学习公式计算作为教师的 Q(s_t, a_t) 值
        expected_state_action_values = self.reward_batch + GAMMA * next_state_values

        return expected_state_action_values

    def update_main_q_network(self):
        '''4. 更新连接参数'''

        # 4.1 切换网络到训练模式
        self.main_q_network.train()

        # 4.2 计算损失函数（smooth_l1_loss 是 Huber 损失）
        # expected_state_action_values 的尺寸为 [minibatch]，所以使用 unsqueeze 将其转换为 [minibatch x 1]
        loss = F.smooth_l1_loss(self.state_action_values,
                                self.expected_state_action_values.unsqueeze(1))

        # 4.3 更新连接参数
        self.optimizer.zero_grad()  # 重置梯度
        loss.backward()  # 计算反向传播
        self.optimizer.step()  # 更新参数

    def update_target_q_network(self):  # DDQN 新增
        '''使 Target Q-Network 与 Main Q-Network 相同'''
        self.target_q_network.load_state_dict(self.main_q_network.state_dict())

# %%
class Agent:

    '''CartPole智能体，带有杆的小车'''
    def __init__(self,num_states,num_actions) -> None:
        self.brain = Brain(num_states,num_actions)
        #为智能体创建大脑以做出决策

    def update_q_function(self):
        '''Q函数的更新'''
        self.brain.replay()

    def get_action(self,state,episode):
        '''动作的确定'''
        action = self.brain.decide_action(state,episode)
        return action
    
    def memorize(self,state,action,state_next,reward):

        self.brain.memory.push(state,action,state_next,reward)
    
    def update_target_q_function(self):

        self.brain.update_target_q_network()

# %%
# 这是一个执行CartPole的环境类


class Environment:

    def __init__(self):
        self.env = gym.make(ENV)  # 设定要执行的任务
        num_states = self.env.observation_space.shape[0]  # 设定任务状态和动作的数量
        num_actions = self.env.action_space.n  # CartPole的动作（向做或向右）数量为2
        self.agent = Agent(num_states, num_actions)  # 创建Agent在环境中执行的动作

        
    def run(self):
        '''执行'''
        episode_10_list = np.zeros(10)  # 存储10个试验的连续站立步骤数，并使用平均步骤数进行输出
        complete_episodes = 0  # 持续站立195步或更多的试验次数
        episode_final = False  # 最终尝试目标
        frames = []  # 用于存储图像的变量，以使最后一轮成为动画

        for episode in range(NUM_EPISODES):  # 重复试验次数
            observation = self.env.reset()  # 环境初始化

            state = observation  # 直接使用观测作为状态state使用
            state = torch.from_numpy(state).type(
                torch.FloatTensor)  # 将NumPy变量转换为PyTorch Tensor
            state = torch.unsqueeze(state, 0)  # size 4转换为size 1x4

            for step in range(MAX_STEPS):  # 1 episode（轮）循环

                # if episode_final is True:  # 在最终试验中，将各时刻图像添加到帧中
                #     frames.append(self.env.render(mode='rgb_array'))

                action = self.agent.get_action(state, episode)  # 求取动作

                # 通过执行动作a_t求s_{t+1}和done标志
                # 从acttion中指定.item()并获取内容
                observation_next, _, done, _ = self.env.step(
                    action.item())  # 使用'_'是因为在面的流程中不适用reward和info

                # 给予奖励。另外，设置episode和state_next的结束评估
                if done:  # 如果step不超过200，或者如果倾斜超过某个角度，则done为true
                    state_next = None  # 没有下一个状态，因此存储为None

                    # 添加到最近的10轮的站立步数列表中
                    episode_10_list = np.hstack(
                        (episode_10_list[1:], step + 1))

                    if step < 195:
                        reward = torch.FloatTensor(
                            [-1.0])  # 如果您在途中倒下，给予奖励-1作为惩罚
                        complete_episodes = 0  # 重置连续成功记录
                    else:
                        reward = torch.FloatTensor([1.0])  # 一直站立直到结束时奖励为1
                        complete_episodes = complete_episodes + 1  # 更新连续记录
                else:
                    reward = torch.FloatTensor([0.0])  # 普通奖励为0
                    state_next = observation_next  # 保持观察不变
                    state_next = torch.from_numpy(state_next).type(
                        torch.FloatTensor)  # 将numpy变量转换为PyTorch Tensor
                    state_next = torch.unsqueeze(state_next, 0)  # size 4转换为size 1x4

                # 向经验池中添加经验
                self.agent.memorize(state, action, state_next, reward)

                # Experience Replay中更新Q函数
                self.agent.update_q_function()

                # 更新观测值
                state = state_next

                # 结束处理
                if done:
                    print('%d Episode: Finished after %d steps：10次试验的平均step数 = %.1lf' % (
                        episode, step + 1, episode_10_list.mean()))
                    if(episode % 2 == 0):
                        self.agent.update_target_q_function()

                    break

            if episode_final is True:
                # 保存并绘制动画
                # display_frames_as_gif(frames)
                break

            # 连续十轮成功
            if complete_episodes >= 100:
                print('10轮连续成功')
                episode_final = True  # 使下一次尝试成为最终绘制的动画

# %%
cartpole_env = Environment()
cartpole_env.run()
# Out:
# Net(
#   (fc1): Linear(in_features=4, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=32, bias=True)
#   (fc3_adv): Linear(in_features=32, out_features=2, bias=True)
#   (fc3_v): Linear(in_features=32, out_features=1, bias=True)
# )
# 0 Episode: Finished after 15 steps：10次试验的平均step数 = 1.5
# 1 Episode: Finished after 8 steps：10次试验的平均step数 = 2.3
# 2 Episode: Finished after 10 steps：10次试验的平均step数 = 3.3
# 3 Episode: Finished after 12 steps：10次试验的平均step数 = 4.5
# 4 Episode: Finished after 11 steps：10次试验的平均step数 = 5.6
# 5 Episode: Finished after 9 steps：10次试验的平均step数 = 6.5
# 6 Episode: Finished after 12 steps：10次试验的平均step数 = 7.7
# 7 Episode: Finished after 10 steps：10次试验的平均step数 = 8.7
# 8 Episode: Finished after 9 steps：10次试验的平均step数 = 9.6
# C:\Users\xulon\AppData\Local\Temp\ipykernel_38948\270896265.py:118: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at ..\aten\src\ATen/native/IndexingUtils.h:28.)
#   a_m[non_final_mask] = self.main_q_network(
# C:\Users\xulon\AppData\Local\Temp\ipykernel_38948\270896265.py:122: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at ..\aten\src\ATen/native/IndexingUtils.h:28.)
#   a_m_non_final_next_states = a_m[non_final_mask].view(-1, 1)
# C:\Users\xulon\AppData\Local\Temp\ipykernel_38948\270896265.py:127: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at ..\aten\src\ATen/native/IndexingUtils.h:28.)
#   next_state_values[non_final_mask] = self.target_q_network(
# 9 Episode: Finished after 9 steps：10次试验的平均step数 = 10.5
# 10 Episode: Finished after 8 steps：10次试验的平均step数 = 9.8
# 11 Episode: Finished after 10 steps：10次试验的平均step数 = 10.0
# 12 Episode: Finished after 10 steps：10次试验的平均step数 = 10.0
# 13 Episode: Finished after 13 steps：10次试验的平均step数 = 10.1
# 14 Episode: Finished after 14 steps：10次试验的平均step数 = 10.4
# 15 Episode: Finished after 13 steps：10次试验的平均step数 = 10.8
# 16 Episode: Finished after 21 steps：10次试验的平均step数 = 11.7
# 17 Episode: Finished after 25 steps：10次试验的平均step数 = 13.2
# 18 Episode: Finished after 25 steps：10次试验的平均step数 = 14.8
# 19 Episode: Finished after 25 steps：10次试验的平均step数 = 16.4
# 20 Episode: Finished after 29 steps：10次试验的平均step数 = 18.5
# 21 Episode: Finished after 33 steps：10次试验的平均step数 = 20.8
# 22 Episode: Finished after 45 steps：10次试验的平均step数 = 24.3
# 23 Episode: Finished after 58 steps：10次试验的平均step数 = 28.8
# 24 Episode: Finished after 131 steps：10次试验的平均step数 = 40.5
# 25 Episode: Finished after 36 steps：10次试验的平均step数 = 42.8
# 26 Episode: Finished after 24 steps：10次试验的平均step数 = 43.1
# 27 Episode: Finished after 24 steps：10次试验的平均step数 = 43.0
# 28 Episode: Finished after 17 steps：10次试验的平均step数 = 42.2
# 29 Episode: Finished after 23 steps：10次试验的平均step数 = 42.0
# 30 Episode: Finished after 25 steps：10次试验的平均step数 = 41.6
# 31 Episode: Finished after 25 steps：10次试验的平均step数 = 40.8
# 32 Episode: Finished after 26 steps：10次试验的平均step数 = 38.9
# 33 Episode: Finished after 16 steps：10次试验的平均step数 = 34.7
# 34 Episode: Finished after 9 steps：10次试验的平均step数 = 22.5
# 35 Episode: Finished after 10 steps：10次试验的平均step数 = 19.9
# 36 Episode: Finished after 13 steps：10次试验的平均step数 = 18.8
# 37 Episode: Finished after 10 steps：10次试验的平均step数 = 17.4
# 38 Episode: Finished after 10 steps：10次试验的平均step数 = 16.7
# 39 Episode: Finished after 16 steps：10次试验的平均step数 = 16.0
# 40 Episode: Finished after 12 steps：10次试验的平均step数 = 14.7
# 41 Episode: Finished after 9 steps：10次试验的平均step数 = 13.1
# 42 Episode: Finished after 10 steps：10次试验的平均step数 = 11.5
# 43 Episode: Finished after 8 steps：10次试验的平均step数 = 10.7
# 44 Episode: Finished after 10 steps：10次试验的平均step数 = 10.8
# 45 Episode: Finished after 9 steps：10次试验的平均step数 = 10.7
# 46 Episode: Finished after 9 steps：10次试验的平均step数 = 10.3
# 47 Episode: Finished after 9 steps：10次试验的平均step数 = 10.2
# 48 Episode: Finished after 9 steps：10次试验的平均step数 = 10.1
# 49 Episode: Finished after 11 steps：10次试验的平均step数 = 9.6
# 50 Episode: Finished after 30 steps：10次试验的平均step数 = 11.4
# 51 Episode: Finished after 28 steps：10次试验的平均step数 = 13.3
# 52 Episode: Finished after 23 steps：10次试验的平均step数 = 14.6
# 53 Episode: Finished after 20 steps：10次试验的平均step数 = 15.8
# 54 Episode: Finished after 31 steps：10次试验的平均step数 = 17.9
# 55 Episode: Finished after 25 steps：10次试验的平均step数 = 19.5
# 56 Episode: Finished after 27 steps：10次试验的平均step数 = 21.3
# 57 Episode: Finished after 35 steps：10次试验的平均step数 = 23.9
# 58 Episode: Finished after 50 steps：10次试验的平均step数 = 28.0
# 59 Episode: Finished after 56 steps：10次试验的平均step数 = 32.5
# 60 Episode: Finished after 58 steps：10次试验的平均step数 = 35.3
# 61 Episode: Finished after 50 steps：10次试验的平均step数 = 37.5
# 62 Episode: Finished after 45 steps：10次试验的平均step数 = 39.7
# 63 Episode: Finished after 68 steps：10次试验的平均step数 = 44.5
# 64 Episode: Finished after 52 steps：10次试验的平均step数 = 46.6
# 65 Episode: Finished after 37 steps：10次试验的平均step数 = 47.8
# 66 Episode: Finished after 39 steps：10次试验的平均step数 = 49.0
# 67 Episode: Finished after 41 steps：10次试验的平均step数 = 49.6
# 68 Episode: Finished after 163 steps：10次试验的平均step数 = 60.9
# 69 Episode: Finished after 38 steps：10次试验的平均step数 = 59.1
# 70 Episode: Finished after 72 steps：10次试验的平均step数 = 60.5
# 71 Episode: Finished after 46 steps：10次试验的平均step数 = 60.1
# 72 Episode: Finished after 39 steps：10次试验的平均step数 = 59.5
# 73 Episode: Finished after 34 steps：10次试验的平均step数 = 56.1
# 74 Episode: Finished after 98 steps：10次试验的平均step数 = 60.7
# 75 Episode: Finished after 58 steps：10次试验的平均step数 = 62.8
# 76 Episode: Finished after 38 steps：10次试验的平均step数 = 62.7
# 77 Episode: Finished after 61 steps：10次试验的平均step数 = 64.7
# 78 Episode: Finished after 35 steps：10次试验的平均step数 = 51.9
# 79 Episode: Finished after 114 steps：10次试验的平均step数 = 59.5
# 80 Episode: Finished after 90 steps：10次试验的平均step数 = 61.3
# 81 Episode: Finished after 34 steps：10次试验的平均step数 = 60.1
# 82 Episode: Finished after 47 steps：10次试验的平均step数 = 60.9
# 83 Episode: Finished after 140 steps：10次试验的平均step数 = 71.5
# 84 Episode: Finished after 46 steps：10次试验的平均step数 = 66.3
# 85 Episode: Finished after 66 steps：10次试验的平均step数 = 67.1
# 86 Episode: Finished after 35 steps：10次试验的平均step数 = 66.8
# 87 Episode: Finished after 34 steps：10次试验的平均step数 = 64.1
# 88 Episode: Finished after 47 steps：10次试验的平均step数 = 65.3
# 89 Episode: Finished after 37 steps：10次试验的平均step数 = 57.6
# 90 Episode: Finished after 49 steps：10次试验的平均step数 = 53.5
# 91 Episode: Finished after 41 steps：10次试验的平均step数 = 54.2
# 92 Episode: Finished after 43 steps：10次试验的平均step数 = 53.8
# 93 Episode: Finished after 48 steps：10次试验的平均step数 = 44.6
# 94 Episode: Finished after 41 steps：10次试验的平均step数 = 44.1
# 95 Episode: Finished after 46 steps：10次试验的平均step数 = 42.1
# 96 Episode: Finished after 61 steps：10次试验的平均step数 = 44.7
# 97 Episode: Finished after 36 steps：10次试验的平均step数 = 44.9
# 98 Episode: Finished after 52 steps：10次试验的平均step数 = 45.4
# 99 Episode: Finished after 45 steps：10次试验的平均step数 = 46.2
# 100 Episode: Finished after 69 steps：10次试验的平均step数 = 48.2
# 101 Episode: Finished after 42 steps：10次试验的平均step数 = 48.3
# 102 Episode: Finished after 45 steps：10次试验的平均step数 = 48.5
# 103 Episode: Finished after 75 steps：10次试验的平均step数 = 51.2
# 104 Episode: Finished after 103 steps：10次试验的平均step数 = 57.4
# 105 Episode: Finished after 41 steps：10次试验的平均step数 = 56.9
# 106 Episode: Finished after 82 steps：10次试验的平均step数 = 59.0
# 107 Episode: Finished after 84 steps：10次试验的平均step数 = 63.8
# 108 Episode: Finished after 97 steps：10次试验的平均step数 = 68.3
# 109 Episode: Finished after 80 steps：10次试验的平均step数 = 71.8
# 110 Episode: Finished after 130 steps：10次试验的平均step数 = 77.9
# 111 Episode: Finished after 86 steps：10次试验的平均step数 = 82.3
# 112 Episode: Finished after 112 steps：10次试验的平均step数 = 89.0
# 113 Episode: Finished after 119 steps：10次试验的平均step数 = 93.4
# 114 Episode: Finished after 80 steps：10次试验的平均step数 = 91.1
# 115 Episode: Finished after 79 steps：10次试验的平均step数 = 94.9
# 116 Episode: Finished after 73 steps：10次试验的平均step数 = 94.0
# 117 Episode: Finished after 107 steps：10次试验的平均step数 = 96.3
# 118 Episode: Finished after 124 steps：10次试验的平均step数 = 99.0
# 119 Episode: Finished after 123 steps：10次试验的平均step数 = 103.3
# 120 Episode: Finished after 80 steps：10次试验的平均step数 = 98.3
# 121 Episode: Finished after 82 steps：10次试验的平均step数 = 97.9
# 122 Episode: Finished after 86 steps：10次试验的平均step数 = 95.3
# 123 Episode: Finished after 128 steps：10次试验的平均step数 = 96.2
# 124 Episode: Finished after 99 steps：10次试验的平均step数 = 98.1
# 125 Episode: Finished after 118 steps：10次试验的平均step数 = 102.0
# 126 Episode: Finished after 172 steps：10次试验的平均step数 = 111.9
# 127 Episode: Finished after 120 steps：10次试验的平均step数 = 113.2
# 128 Episode: Finished after 150 steps：10次试验的平均step数 = 115.8
# 129 Episode: Finished after 117 steps：10次试验的平均step数 = 115.2
# 130 Episode: Finished after 108 steps：10次试验的平均step数 = 118.0
# 131 Episode: Finished after 148 steps：10次试验的平均step数 = 124.6
# 132 Episode: Finished after 103 steps：10次试验的平均step数 = 126.3
# 133 Episode: Finished after 136 steps：10次试验的平均step数 = 127.1
# 134 Episode: Finished after 147 steps：10次试验的平均step数 = 131.9
# 135 Episode: Finished after 123 steps：10次试验的平均step数 = 132.4
# 136 Episode: Finished after 120 steps：10次试验的平均step数 = 127.2
# 137 Episode: Finished after 123 steps：10次试验的平均step数 = 127.5
# 138 Episode: Finished after 131 steps：10次试验的平均step数 = 125.6
# 139 Episode: Finished after 120 steps：10次试验的平均step数 = 125.9
# 140 Episode: Finished after 168 steps：10次试验的平均step数 = 131.9
# 141 Episode: Finished after 107 steps：10次试验的平均step数 = 127.8
# 142 Episode: Finished after 124 steps：10次试验的平均step数 = 129.9
# 143 Episode: Finished after 127 steps：10次试验的平均step数 = 129.0
# 144 Episode: Finished after 200 steps：10次试验的平均step数 = 134.3
# 145 Episode: Finished after 123 steps：10次试验的平均step数 = 134.3
# 146 Episode: Finished after 178 steps：10次试验的平均step数 = 140.1
# 147 Episode: Finished after 145 steps：10次试验的平均step数 = 142.3
# 148 Episode: Finished after 117 steps：10次试验的平均step数 = 140.9
# 149 Episode: Finished after 123 steps：10次试验的平均step数 = 141.2
# 150 Episode: Finished after 126 steps：10次试验的平均step数 = 137.0
# 151 Episode: Finished after 180 steps：10次试验的平均step数 = 144.3
# 152 Episode: Finished after 173 steps：10次试验的平均step数 = 149.2
# 153 Episode: Finished after 141 steps：10次试验的平均step数 = 150.6
# 154 Episode: Finished after 192 steps：10次试验的平均step数 = 149.8
# 155 Episode: Finished after 117 steps：10次试验的平均step数 = 149.2
# 156 Episode: Finished after 148 steps：10次试验的平均step数 = 146.2
# 157 Episode: Finished after 125 steps：10次试验的平均step数 = 144.2
# 158 Episode: Finished after 154 steps：10次试验的平均step数 = 147.9
# 159 Episode: Finished after 139 steps：10次试验的平均step数 = 149.5
# 160 Episode: Finished after 126 steps：10次试验的平均step数 = 149.5
# 161 Episode: Finished after 138 steps：10次试验的平均step数 = 145.3
# 162 Episode: Finished after 156 steps：10次试验的平均step数 = 143.6
# 163 Episode: Finished after 174 steps：10次试验的平均step数 = 146.9
# 164 Episode: Finished after 139 steps：10次试验的平均step数 = 141.6
# 165 Episode: Finished after 130 steps：10次试验的平均step数 = 142.9
# 166 Episode: Finished after 141 steps：10次试验的平均step数 = 142.2
# 167 Episode: Finished after 167 steps：10次试验的平均step数 = 146.4
# 168 Episode: Finished after 137 steps：10次试验的平均step数 = 144.7
# 169 Episode: Finished after 141 steps：10次试验的平均step数 = 144.9
# 170 Episode: Finished after 169 steps：10次试验的平均step数 = 149.2
# 171 Episode: Finished after 158 steps：10次试验的平均step数 = 151.2
# 172 Episode: Finished after 170 steps：10次试验的平均step数 = 152.6
# 173 Episode: Finished after 151 steps：10次试验的平均step数 = 150.3
# 174 Episode: Finished after 172 steps：10次试验的平均step数 = 153.6
# 175 Episode: Finished after 151 steps：10次试验的平均step数 = 155.7
# 176 Episode: Finished after 192 steps：10次试验的平均step数 = 160.8
# 177 Episode: Finished after 139 steps：10次试验的平均step数 = 158.0
# 178 Episode: Finished after 139 steps：10次试验的平均step数 = 158.2
# 179 Episode: Finished after 141 steps：10次试验的平均step数 = 158.2
# 180 Episode: Finished after 126 steps：10次试验的平均step数 = 153.9
# 181 Episode: Finished after 173 steps：10次试验的平均step数 = 155.4
# 182 Episode: Finished after 172 steps：10次试验的平均step数 = 155.6
# 183 Episode: Finished after 200 steps：10次试验的平均step数 = 160.5
# 184 Episode: Finished after 156 steps：10次试验的平均step数 = 158.9
# 185 Episode: Finished after 133 steps：10次试验的平均step数 = 157.1
# 186 Episode: Finished after 165 steps：10次试验的平均step数 = 154.4
# 187 Episode: Finished after 154 steps：10次试验的平均step数 = 155.9
# 188 Episode: Finished after 129 steps：10次试验的平均step数 = 154.9
# 189 Episode: Finished after 120 steps：10次试验的平均step数 = 152.8
# 190 Episode: Finished after 147 steps：10次试验的平均step数 = 154.9
# 191 Episode: Finished after 149 steps：10次试验的平均step数 = 152.5
# 192 Episode: Finished after 150 steps：10次试验的平均step数 = 150.3
# 193 Episode: Finished after 120 steps：10次试验的平均step数 = 142.3
# 194 Episode: Finished after 147 steps：10次试验的平均step数 = 141.4
# 195 Episode: Finished after 135 steps：10次试验的平均step数 = 141.6
# 196 Episode: Finished after 200 steps：10次试验的平均step数 = 145.1
# 197 Episode: Finished after 193 steps：10次试验的平均step数 = 149.0
# 198 Episode: Finished after 157 steps：10次试验的平均step数 = 151.8
# 199 Episode: Finished after 129 steps：10次试验的平均step数 = 152.7
# 200 Episode: Finished after 145 steps：10次试验的平均step数 = 152.5
# 201 Episode: Finished after 180 steps：10次试验的平均step数 = 155.6
# 202 Episode: Finished after 135 steps：10次试验的平均step数 = 154.1
# 203 Episode: Finished after 152 steps：10次试验的平均step数 = 157.3
# 204 Episode: Finished after 145 steps：10次试验的平均step数 = 157.1
# 205 Episode: Finished after 153 steps：10次试验的平均step数 = 158.9
# 206 Episode: Finished after 165 steps：10次试验的平均step数 = 155.4
# 207 Episode: Finished after 156 steps：10次试验的平均step数 = 151.7
# 208 Episode: Finished after 166 steps：10次试验的平均step数 = 152.6
# 209 Episode: Finished after 200 steps：10次试验的平均step数 = 159.7
# 210 Episode: Finished after 200 steps：10次试验的平均step数 = 165.2
# 211 Episode: Finished after 126 steps：10次试验的平均step数 = 159.8
# 212 Episode: Finished after 140 steps：10次试验的平均step数 = 160.3
# 213 Episode: Finished after 139 steps：10次试验的平均step数 = 159.0
# 214 Episode: Finished after 140 steps：10次试验的平均step数 = 158.5
# 215 Episode: Finished after 200 steps：10次试验的平均step数 = 163.2
# 216 Episode: Finished after 147 steps：10次试验的平均step数 = 161.4
# 217 Episode: Finished after 122 steps：10次试验的平均step数 = 158.0
# 218 Episode: Finished after 200 steps：10次试验的平均step数 = 161.4
# 219 Episode: Finished after 170 steps：10次试验的平均step数 = 158.4
# 220 Episode: Finished after 150 steps：10次试验的平均step数 = 153.4
# 221 Episode: Finished after 158 steps：10次试验的平均step数 = 156.6
# 222 Episode: Finished after 200 steps：10次试验的平均step数 = 162.6
# 223 Episode: Finished after 197 steps：10次试验的平均step数 = 168.4
# 224 Episode: Finished after 200 steps：10次试验的平均step数 = 174.4
# 225 Episode: Finished after 171 steps：10次试验的平均step数 = 171.5
# 226 Episode: Finished after 200 steps：10次试验的平均step数 = 176.8
# 227 Episode: Finished after 200 steps：10次试验的平均step数 = 184.6
# 228 Episode: Finished after 181 steps：10次试验的平均step数 = 182.7
# 229 Episode: Finished after 200 steps：10次试验的平均step数 = 185.7
# 230 Episode: Finished after 154 steps：10次试验的平均step数 = 186.1
# 231 Episode: Finished after 172 steps：10次试验的平均step数 = 187.5
# 232 Episode: Finished after 200 steps：10次试验的平均step数 = 187.5
# 233 Episode: Finished after 200 steps：10次试验的平均step数 = 187.8
# 234 Episode: Finished after 200 steps：10次试验的平均step数 = 187.8
# 235 Episode: Finished after 200 steps：10次试验的平均step数 = 190.7
# 236 Episode: Finished after 200 steps：10次试验的平均step数 = 190.7
# 237 Episode: Finished after 195 steps：10次试验的平均step数 = 190.2
# 238 Episode: Finished after 172 steps：10次试验的平均step数 = 189.3
# 239 Episode: Finished after 200 steps：10次试验的平均step数 = 189.3
# 240 Episode: Finished after 200 steps：10次试验的平均step数 = 193.9
# 241 Episode: Finished after 200 steps：10次试验的平均step数 = 196.7
# 242 Episode: Finished after 200 steps：10次试验的平均step数 = 196.7
# 243 Episode: Finished after 198 steps：10次试验的平均step数 = 196.5
# 244 Episode: Finished after 200 steps：10次试验的平均step数 = 196.5
# 245 Episode: Finished after 200 steps：10次试验的平均step数 = 196.5
# 246 Episode: Finished after 200 steps：10次试验的平均step数 = 196.5
# 247 Episode: Finished after 200 steps：10次试验的平均step数 = 197.0
# 248 Episode: Finished after 187 steps：10次试验的平均step数 = 198.5
# 249 Episode: Finished after 200 steps：10次试验的平均step数 = 198.5
# 250 Episode: Finished after 175 steps：10次试验的平均step数 = 196.0
# 251 Episode: Finished after 200 steps：10次试验的平均step数 = 196.0
# 252 Episode: Finished after 134 steps：10次试验的平均step数 = 189.4
# 253 Episode: Finished after 59 steps：10次试验的平均step数 = 175.5
# 254 Episode: Finished after 187 steps：10次试验的平均step数 = 174.2
# 255 Episode: Finished after 200 steps：10次试验的平均step数 = 174.2
# 256 Episode: Finished after 200 steps：10次试验的平均step数 = 174.2
# 257 Episode: Finished after 200 steps：10次试验的平均step数 = 174.2
# 258 Episode: Finished after 200 steps：10次试验的平均step数 = 175.5
# 259 Episode: Finished after 200 steps：10次试验的平均step数 = 175.5
# 260 Episode: Finished after 200 steps：10次试验的平均step数 = 178.0
# 261 Episode: Finished after 200 steps：10次试验的平均step数 = 178.0
# 262 Episode: Finished after 200 steps：10次试验的平均step数 = 184.6
# 263 Episode: Finished after 200 steps：10次试验的平均step数 = 198.7
# 264 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 265 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 266 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 267 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 268 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 269 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 270 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 271 Episode: Finished after 196 steps：10次试验的平均step数 = 199.6
# 272 Episode: Finished after 200 steps：10次试验的平均step数 = 199.6
# 273 Episode: Finished after 200 steps：10次试验的平均step数 = 199.6
# 274 Episode: Finished after 200 steps：10次试验的平均step数 = 199.6
# 275 Episode: Finished after 200 steps：10次试验的平均step数 = 199.6
# 276 Episode: Finished after 200 steps：10次试验的平均step数 = 199.6
# 277 Episode: Finished after 200 steps：10次试验的平均step数 = 199.6
# 278 Episode: Finished after 200 steps：10次试验的平均step数 = 199.6
# 279 Episode: Finished after 200 steps：10次试验的平均step数 = 199.6
# 280 Episode: Finished after 200 steps：10次试验的平均step数 = 199.6
# 281 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 282 Episode: Finished after 199 steps：10次试验的平均step数 = 199.9
# 283 Episode: Finished after 197 steps：10次试验的平均step数 = 199.6
# 284 Episode: Finished after 200 steps：10次试验的平均step数 = 199.6
# 285 Episode: Finished after 198 steps：10次试验的平均step数 = 199.4
# 286 Episode: Finished after 191 steps：10次试验的平均step数 = 198.5
# 287 Episode: Finished after 200 steps：10次试验的平均step数 = 198.5
# 288 Episode: Finished after 200 steps：10次试验的平均step数 = 198.5
# 289 Episode: Finished after 200 steps：10次试验的平均step数 = 198.5
# 290 Episode: Finished after 166 steps：10次试验的平均step数 = 195.1
# 291 Episode: Finished after 200 steps：10次试验的平均step数 = 195.1
# 292 Episode: Finished after 200 steps：10次试验的平均step数 = 195.2
# 293 Episode: Finished after 200 steps：10次试验的平均step数 = 195.5
# 294 Episode: Finished after 200 steps：10次试验的平均step数 = 195.5
# 295 Episode: Finished after 200 steps：10次试验的平均step数 = 195.7
# 296 Episode: Finished after 200 steps：10次试验的平均step数 = 196.6
# 297 Episode: Finished after 200 steps：10次试验的平均step数 = 196.6
# 298 Episode: Finished after 200 steps：10次试验的平均step数 = 196.6
# 299 Episode: Finished after 163 steps：10次试验的平均step数 = 192.9
# 300 Episode: Finished after 200 steps：10次试验的平均step数 = 196.3
# 301 Episode: Finished after 200 steps：10次试验的平均step数 = 196.3
# 302 Episode: Finished after 200 steps：10次试验的平均step数 = 196.3
# 303 Episode: Finished after 200 steps：10次试验的平均step数 = 196.3
# 304 Episode: Finished after 200 steps：10次试验的平均step数 = 196.3
# 305 Episode: Finished after 200 steps：10次试验的平均step数 = 196.3
# 306 Episode: Finished after 200 steps：10次试验的平均step数 = 196.3
# 307 Episode: Finished after 153 steps：10次试验的平均step数 = 191.6
# 308 Episode: Finished after 200 steps：10次试验的平均step数 = 191.6
# 309 Episode: Finished after 158 steps：10次试验的平均step数 = 191.1
# 310 Episode: Finished after 192 steps：10次试验的平均step数 = 190.3
# 311 Episode: Finished after 199 steps：10次试验的平均step数 = 190.2
# 312 Episode: Finished after 169 steps：10次试验的平均step数 = 187.1
# 313 Episode: Finished after 200 steps：10次试验的平均step数 = 187.1
# 314 Episode: Finished after 163 steps：10次试验的平均step数 = 183.4
# 315 Episode: Finished after 200 steps：10次试验的平均step数 = 183.4
# 316 Episode: Finished after 200 steps：10次试验的平均step数 = 183.4
# 317 Episode: Finished after 200 steps：10次试验的平均step数 = 188.1
# 318 Episode: Finished after 200 steps：10次试验的平均step数 = 188.1
# 319 Episode: Finished after 200 steps：10次试验的平均step数 = 192.3
# 320 Episode: Finished after 200 steps：10次试验的平均step数 = 193.1
# 321 Episode: Finished after 200 steps：10次试验的平均step数 = 193.2
# 322 Episode: Finished after 200 steps：10次试验的平均step数 = 196.3
# 323 Episode: Finished after 200 steps：10次试验的平均step数 = 196.3
# 324 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 325 Episode: Finished after 149 steps：10次试验的平均step数 = 194.9
# 326 Episode: Finished after 162 steps：10次试验的平均step数 = 191.1
# 327 Episode: Finished after 139 steps：10次试验的平均step数 = 185.0
# 328 Episode: Finished after 161 steps：10次试验的平均step数 = 181.1
# 329 Episode: Finished after 109 steps：10次试验的平均step数 = 172.0
# 330 Episode: Finished after 117 steps：10次试验的平均step数 = 163.7
# 331 Episode: Finished after 123 steps：10次试验的平均step数 = 156.0
# 332 Episode: Finished after 119 steps：10次试验的平均step数 = 147.9
# 333 Episode: Finished after 168 steps：10次试验的平均step数 = 144.7
# 334 Episode: Finished after 160 steps：10次试验的平均step数 = 140.7
# 335 Episode: Finished after 158 steps：10次试验的平均step数 = 141.6
# 336 Episode: Finished after 198 steps：10次试验的平均step数 = 145.2
# 337 Episode: Finished after 200 steps：10次试验的平均step数 = 151.3
# 338 Episode: Finished after 190 steps：10次试验的平均step数 = 154.2
# 339 Episode: Finished after 200 steps：10次试验的平均step数 = 163.3
# 340 Episode: Finished after 200 steps：10次试验的平均step数 = 171.6
# 341 Episode: Finished after 199 steps：10次试验的平均step数 = 179.2
# 342 Episode: Finished after 200 steps：10次试验的平均step数 = 187.3
# 343 Episode: Finished after 200 steps：10次试验的平均step数 = 190.5
# 344 Episode: Finished after 200 steps：10次试验的平均step数 = 194.5
# 345 Episode: Finished after 200 steps：10次试验的平均step数 = 198.7
# 346 Episode: Finished after 169 steps：10次试验的平均step数 = 195.8
# 347 Episode: Finished after 200 steps：10次试验的平均step数 = 195.8
# 348 Episode: Finished after 200 steps：10次试验的平均step数 = 196.8
# 349 Episode: Finished after 200 steps：10次试验的平均step数 = 196.8
# 350 Episode: Finished after 200 steps：10次试验的平均step数 = 196.8
# 351 Episode: Finished after 200 steps：10次试验的平均step数 = 196.9
# 352 Episode: Finished after 200 steps：10次试验的平均step数 = 196.9
# 353 Episode: Finished after 152 steps：10次试验的平均step数 = 192.1
# 354 Episode: Finished after 148 steps：10次试验的平均step数 = 186.9
# 355 Episode: Finished after 200 steps：10次试验的平均step数 = 186.9
# 356 Episode: Finished after 200 steps：10次试验的平均step数 = 190.0
# 357 Episode: Finished after 137 steps：10次试验的平均step数 = 183.7
# 358 Episode: Finished after 120 steps：10次试验的平均step数 = 175.7
# 359 Episode: Finished after 153 steps：10次试验的平均step数 = 171.0
# 360 Episode: Finished after 200 steps：10次试验的平均step数 = 171.0
# 361 Episode: Finished after 172 steps：10次试验的平均step数 = 168.2
# 362 Episode: Finished after 114 steps：10次试验的平均step数 = 159.6
# 363 Episode: Finished after 185 steps：10次试验的平均step数 = 162.9
# 364 Episode: Finished after 200 steps：10次试验的平均step数 = 168.1
# 365 Episode: Finished after 171 steps：10次试验的平均step数 = 165.2
# 366 Episode: Finished after 110 steps：10次试验的平均step数 = 156.2
# 367 Episode: Finished after 114 steps：10次试验的平均step数 = 153.9
# 368 Episode: Finished after 154 steps：10次试验的平均step数 = 157.3
# 369 Episode: Finished after 125 steps：10次试验的平均step数 = 154.5
# 370 Episode: Finished after 25 steps：10次试验的平均step数 = 137.0
# 371 Episode: Finished after 144 steps：10次试验的平均step数 = 134.2
# 372 Episode: Finished after 31 steps：10次试验的平均step数 = 125.9
# 373 Episode: Finished after 25 steps：10次试验的平均step数 = 109.9
# 374 Episode: Finished after 27 steps：10次试验的平均step数 = 92.6
# 375 Episode: Finished after 112 steps：10次试验的平均step数 = 86.7
# 376 Episode: Finished after 121 steps：10次试验的平均step数 = 87.8
# 377 Episode: Finished after 16 steps：10次试验的平均step数 = 78.0
# 378 Episode: Finished after 27 steps：10次试验的平均step数 = 65.3
# 379 Episode: Finished after 126 steps：10次试验的平均step数 = 65.4
# 380 Episode: Finished after 15 steps：10次试验的平均step数 = 64.4
# 381 Episode: Finished after 122 steps：10次试验的平均step数 = 62.2
# 382 Episode: Finished after 23 steps：10次试验的平均step数 = 61.4
# 383 Episode: Finished after 139 steps：10次试验的平均step数 = 72.8
# 384 Episode: Finished after 21 steps：10次试验的平均step数 = 72.2
# 385 Episode: Finished after 136 steps：10次试验的平均step数 = 74.6
# 386 Episode: Finished after 200 steps：10次试验的平均step数 = 82.5
# 387 Episode: Finished after 200 steps：10次试验的平均step数 = 100.9
# 388 Episode: Finished after 200 steps：10次试验的平均step数 = 118.2
# 389 Episode: Finished after 200 steps：10次试验的平均step数 = 125.6
# 390 Episode: Finished after 200 steps：10次试验的平均step数 = 144.1
# 391 Episode: Finished after 200 steps：10次试验的平均step数 = 151.9
# 392 Episode: Finished after 200 steps：10次试验的平均step数 = 169.6
# 393 Episode: Finished after 200 steps：10次试验的平均step数 = 175.7
# 394 Episode: Finished after 14 steps：10次试验的平均step数 = 175.0
# 395 Episode: Finished after 200 steps：10次试验的平均step数 = 181.4
# 396 Episode: Finished after 200 steps：10次试验的平均step数 = 181.4
# 397 Episode: Finished after 200 steps：10次试验的平均step数 = 181.4
# 398 Episode: Finished after 200 steps：10次试验的平均step数 = 181.4
# 399 Episode: Finished after 200 steps：10次试验的平均step数 = 181.4
# 400 Episode: Finished after 200 steps：10次试验的平均step数 = 181.4
# 401 Episode: Finished after 200 steps：10次试验的平均step数 = 181.4
# 402 Episode: Finished after 200 steps：10次试验的平均step数 = 181.4
# 403 Episode: Finished after 200 steps：10次试验的平均step数 = 181.4
# 404 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 405 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 406 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 407 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 408 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 409 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 410 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 411 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 412 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 413 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 414 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 415 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 416 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 417 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 418 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 419 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 420 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 421 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 422 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 423 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 424 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 425 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 426 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 427 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 428 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 429 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 430 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 431 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 432 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 433 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 434 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 435 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 436 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 437 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 438 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 439 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 440 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 441 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 442 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 443 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 444 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 445 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 446 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 447 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 448 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 449 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 450 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 451 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 452 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 453 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 454 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 455 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 456 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 457 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 458 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 459 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 460 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 461 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 462 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 463 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 464 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 465 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 466 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 467 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 468 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 469 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 470 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 471 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 472 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 473 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 474 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 475 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 476 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 477 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 478 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 479 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 480 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 481 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 482 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 483 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 484 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 485 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 486 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 487 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 488 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 489 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 490 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 491 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 492 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 493 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 494 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
# 10轮连续成功
# 495 Episode: Finished after 200 steps：10次试验的平均step数 = 200.0
